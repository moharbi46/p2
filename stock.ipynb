# %%
import yfinance as yf
import pandas as pd

# %%
tesla = yf.Ticker("TSLA")

# %%
tesla_data = tesla.history(period="1mo")

# %%
tesla_data.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-10-22 00:00:00-04:00  217.309998  218.220001  215.259995  217.970001
# 2024-10-23 00:00:00-04:00  217.130005  218.720001  212.110001  213.649994
# 2024-10-24 00:00:00-04:00  244.679993  262.119995  242.649994  260.480011
# 2024-10-25 00:00:00-04:00  256.010010  269.489990  255.320007  269.190002
# 2024-10-28 00:00:00-04:00  270.000000  273.540009  262.239990  262.510010
#
#                               Volume  Dividends  Stock Splits
# Date
# 2024-10-22 00:00:00-04:00   43268700        0.0           0.0
# 2024-10-23 00:00:00-04:00   80938900        0.0           0.0
# 2024-10-24 00:00:00-04:00  204491900        0.0           0.0
# 2024-10-25 00:00:00-04:00  161611900        0.0           0.0
# 2024-10-28 00:00:00-04:00  107653600        0.0           0.0

# %%
# !pip install pandas
# !pip install requests
# !pip install bs4
# !pip install html5lib 
# !pip install lxml
# !pip install plotly

# %%
import requests
from bs4 import BeautifulSoup

# %%
url="https://companiesmarketcap.com/tesla/revenue"

# %%
data  = requests.get(url).text

# %%
soup = BeautifulSoup(data, 'html.parser')

# %%
tesla_data=pd.DataFrame(columns=['Year','Revenue'])

# %%
for row in soup.find("tbody").find_all('tr'):
    col = row.find_all('td')  # Define 'col' by finding all 'td' elements in the current row
    Year = col[0].text  # Extract the year from the first column
    Revenue = col[1].text  # Extract the revenue from the second column
    
    # Concatenate the new data to the existing DataFrame
    tesla_data = pd.concat([tesla_data, pd.DataFrame({"Year": [Year], "Revenue": [Revenue]})], ignore_index=True)

# %%
tesla_data.head()
# Out:
#           Year   Revenue
# 0  2024 (TTM)   $97.15 B
# 1        2023   $96.77 B
# 2        2022   $81.46 B
# 3        2021   $53.82 B
# 4        2020   $31.53 B

# %%
gamestop=yf.Ticker("GME")

# %%
GME_Data=gamestop.history(period="1mo")

# %%
GME_Data.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2024-10-22 00:00:00-04:00  20.620001  20.940001  20.430000  20.930000
# 2024-10-23 00:00:00-04:00  20.730000  20.980000  20.350000  20.540001
# 2024-10-24 00:00:00-04:00  20.629999  20.840000  20.480000  20.629999
# 2024-10-25 00:00:00-04:00  20.650000  21.430000  20.540001  20.570000
# 2024-10-28 00:00:00-04:00  20.840000  22.770000  20.730000  22.730000
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-10-22 00:00:00-04:00   3232300        0.0           0.0
# 2024-10-23 00:00:00-04:00   2945000        0.0           0.0
# 2024-10-24 00:00:00-04:00   2682300        0.0           0.0
# 2024-10-25 00:00:00-04:00   5989000        0.0           0.0
# 2024-10-28 00:00:00-04:00  13641200        0.0           0.0

# %%
url_2="https://companiesmarketcap.com/gamestop/revenue/"

# %%
gme_data=requests.get(url).text

# %%
soup = BeautifulSoup(gme_data, 'html.parser')

# %%
gme_data=pd.DataFrame(columns=['Year','Revenue'])

# %%
for row in soup.find("tbody").find_all('tr'):
    col = row.find_all('td')  # Define 'col' by finding all 'td' elements in the current row
    Year = col[0].text  # Extract the year from the first column
    Revenue = col[1].text  # Extract the revenue from the second column
    
    # Concatenate the new data to the existing DataFrame
    gme_data = pd.concat([gme_data, pd.DataFrame({"Year": [Year], "Revenue": [Revenue]})], ignore_index=True)

# %%
gme_data.head()
# Out:
#           Year   Revenue
# 0  2024 (TTM)   $97.15 B
# 1        2023   $96.77 B
# 2        2022   $81.46 B
# 3        2021   $53.82 B
# 4        2020   $31.53 B

# %%
gme_data['Year'] = gme_data['Year'].astype(str)

# Plotting the graph
plt.figure(figsize=(10, 5))  # Set the figure size
plt.plot(gme_data['Year'], gme_data['Revenue'], marker='o')  # Line plot with markers
plt.title('Revenue Over Years')  # Title of the graph
plt.xlabel('Year')  # X-axis label
plt.ylabel('Revenue')  # Y-axis label
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid()  # Add grid for better visualization
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()  # Display the graph

# %%
tesla_data['Year'] = tesla_data['Year'].astype(str)

# Plotting the graph
plt.figure(figsize=(10, 5))  # Set the figure size
plt.plot(tesla_data['Year'], gme_data['Revenue'], marker='o')  # Line plot with markers
plt.title('Revenue Over Years')  # Title of the graph
plt.xlabel('Year')  # X-axis label
plt.ylabel('Revenue')  # Y-axis label
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid()  # Add grid for better visualization
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()  # Display the graph
